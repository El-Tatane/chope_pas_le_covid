# %%
#Import bibli
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('max_colwidth',800)

#Import csv
confirm=pd.read_csv('../../dataset/global/time_series_covid19_confirmed_global.csv', sep = ',')
deaths =pd.read_csv('../../dataset/global/time_series_covid19_deaths_global.csv', sep = ',')
recover=pd.read_csv('../../dataset/global/time_series_covid19_recovered_global.csv', sep = ',')

dict_csv={"confirm":confirm,"deaths":deaths,"recover":recover}

#Modification des csv
confirm.index=confirm["Country/Region"]
confirm=confirm.drop(columns=["Country/Region",'Lat','Long','Province/State'])
confirm=confirm.groupby("Country/Region").sum()

deaths.index=deaths["Country/Region"]
deaths=deaths.drop(columns=["Country/Region",'Lat','Long','Province/State'])
deaths=deaths.groupby("Country/Region").sum()


recover.index=recover["Country/Region"]
recover=recover.drop(columns=["Country/Region",'Lat','Long','Province/State'])
recover=recover.groupby("Country/Region").sum()

# %%
confirm
# Out:
#                     1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan               0        0        0        0        0        0
# Albania                   0        0        0        0        0        0
# Algeria                   0        0        0        0        0        0
# Andorra                   0        0        0        0        0        0
# Angola                    0        0        0        0        0        0
# ...                     ...      ...      ...      ...      ...      ...
# West Bank and Gaza        0        0        0        0        0        0
# Western Sahara            0        0        0        0        0        0
# Yemen                     0        0        0        0        0        0
# Zambia                    0        0        0        0        0        0
# Zimbabwe                  0        0        0        0        0        0
#
#                     1/28/20  1/29/20  1/30/20  1/31/20  2/1/20  2/2/20  \
# ...

# %%
fr=conf_by_country('France')
fr.plot.line()

# %% [markdown]
# ### Methode

# %%
def conf_by_country(country):
    return confirm.loc[country]
